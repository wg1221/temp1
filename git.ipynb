# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e54e23fc-5c87-491e-88e1-a91af389e464" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e54e23fc-5c87-491e-88e1-a91af389e464">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://wg1221: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@github.com/wg1221/temp1/
# Out:
# Cloning into 'temp1'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 17 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), done.

# %%
cd temp1
# Out:
# [Errno 2] No such file or directory: 'temp1'
# /content/drive/MyDrive/Colab Notebooks/temp1

# %%
# !git config --global user.email 'woongyu1221@gmail.com'
# !git config --global user.name 'wg1221'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	"\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263.ipynb"
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add 깃허브.ipynb
# !git commit -m "Connect Google Colab and Drive"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
# 	"\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263.ipynb"
#
# nothing added to commit but untracked files present

# %%
# !git push -u origin main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date

# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning) # FutureWarning 제거
pd.options.display.float_format = '{:.0f}'.format

# %%
data = pd.read_csv('/content/버스노선.csv',encoding = 'euc-kr')

# %%
data
# Out:
#        arsno    bstopid   lineno    nodenm  gpsx  gpsy bustype      lineid
# 0      01001  167970102      186     영주삼거리   129    35    일반버스  5200186000
# 1      01001  167970102      190     영주삼거리   129    35    일반버스  5200190000
# 2      01001  167970102       38     영주삼거리   129    35    일반버스  5200038000
# 3      01001  167970102      508     영주삼거리   129    35    일반버스  5200508000
# 4      01001  167970102       86     영주삼거리   129    35    일반버스  5200086000
# ...      ...        ...      ...       ...   ...   ...     ...         ...
# 21824         185070202  해운대구3-2      홈플러스   129    35    마을버스  5290903200
# 21825         508550000    부산진구9       개금역   129    35    마을버스  5290509000
# 21826         508580000      183     농심가슈퍼   129    35    일반버스  5200183000
# 21827         509270000     기장군8  동해선일광역광장   129    35    마을버스  5291608000
# 21828         510410000      중구1     덕산아파트   129    35    마을버스  5290101000
#
# [21829 rows x 8 columns]
